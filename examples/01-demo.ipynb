# %% [markdown]
# # Yukti Jupyter Extension Demo

# %%
# %load_ext yukti

# %%
# %%ask
# give me code for fibonacci, but three different versions with increasing efficiency on large numbers
# also give me the formulae for each of those as separate markdown prose. Just the formula is sufficient
# Out:
# Added three Fibonacci implementations with increasing efficiency: recursive, iterative, and fast doubling, each preceded by its formula.

# %% [markdown]
# $$F_0=0,\quad F_1=1,\quad F_n=F_{n-1}+F_{n-2}\;(n\ge2)$$

# %%
def fib_recursive(n):
    """Return F_n using direct recursion: O(2^n) time, O(n) space."""
    if n < 0:
        raise ValueError("n must be non-negative")
    if n < 2:
        return n
    return fib_recursive(n - 1) + fib_recursive(n - 2)

# %% [markdown]
# $$(F_k,F_{k+1})\leftarrow(F_{k+1},F_k+F_{k+1}),\qquad (F_0,F_1)=(0,1)$$

# %%
def fib_iterative(n):
    """Return F_n iteratively: O(n) time, O(1) space."""
    if n < 0:
        raise ValueError("n must be non-negative")
    a, b = 0, 1
    for _ in range(n):
        a, b = b, a + b
    return a

# %% [markdown]
# $$
# F_{2k}=F_k(2F_{k+1}-F_k)
# \quad
# F_{2k+1}=F_k^2+F_{k+1}^2
# $$

# %%
def fib_fast_doubling(n):
    """Return F_n using fast doubling: O(log n) arithmetic steps."""
    if n < 0:
        raise ValueError("n must be non-negative")

    def pair(k):
        if k == 0:
            return 0, 1
        a, b = pair(k // 2)
        c = a * (2 * b - a)
        d = a * a + b * b
        return (d, c + d) if k % 2 else (c, d)

    return pair(n)[0]

# %%
# %timeit -n 5 fib_recursive(40)
# %timeit -n 5 fib_iterative(10)
# %timeit -n 5 fib_fast_doubling(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 get_ipython().run_line_magic('timeit', '-n 5 fib_recursive(40)')
#       3 get_ipython().run_line_magic('timeit', '-n 5 fib_iterative(10)')
#       5 get_ipython().run_line_magic('timeit', '-n 5 fib_fast_doubling(10)')
#
# File ~/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2511, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2509     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2510 with self.builtin_trap:
# -> 2511     result = fn(*args, **kwargs)
#    2513 # The code below prevents the output from being displayed
#    2514 # when using magics with decorator @output_can_be_silenced
#    2515 # when the last Python token in the expression is a ';'.
#    2516 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.venv/lib/python3.12/site-packages/IPython/core/magics/execution.py:1226, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1223         if time_number >= 0.2:
#    1224             break
# -> 1226 all_runs = timer.repeat(repeat, number)
#    1227 best = min(all_runs) / number
#    1228 worst = max(all_runs) / number
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/timeit.py:208, in Timer.repeat(self, repeat, number)
#     206 r = []
#     207 for i in range(repeat):
# --> 208     t = self.timeit(number)
#     209     r.append(t)
#     210 return r
#
# File ~/.venv/lib/python3.12/site-packages/IPython/core/magics/execution.py:184, in Timer.timeit(self, number)
#     182 gc.disable()
#     183 try:
# --> 184     timing = self.inner(it, self.timer)
#     185 finally:
#     186     if gcold:
#
# File <magic-timeit>:1, in inner(_it, _timer)
#
# Cell In[2], line 7, in fib_recursive(n)
#       5 if n < 2:
#       6     return n
# ----> 7 return fib_recursive(n - 1) + fib_recursive(n - 2)
#
# Cell In[2], line 7, in fib_recursive(n)
#       5 if n < 2:
#       6     return n
# ----> 7 return fib_recursive(n - 1) + fib_recursive(n - 2)
#
#     [... skipping similar frames: fib_recursive at line 7 (27 times)]
#
# Cell In[2], line 7, in fib_recursive(n)
#       5 if n < 2:
#       6     return n
# ----> 7 return fib_recursive(n - 1) + fib_recursive(n - 2)
#
# Cell In[2], line 1, in fib_recursive(n)
# ----> 1 def fib_recursive(n):
#       2     """Return F_n using direct recursion: O(2^n) time, O(n) space."""
#       3     if n < 0:
#
# KeyboardInterrupt:

# %%
# %%ask
# how to run %time only once or like 5 times
# Out:
# `%time` runs the expression **once** (with internal bookkeeping):
#
# ```python
# %time fib_recursive(40)
# ```
#
# To benchmark multiple executions, use `%timeit` with `-n`:
#
# ```python
# %timeit -n 5 -r 1 fib_recursive(40)
# ```
#
# - `-n 5`: execute **5 times per repeat**
# - `-r 1`: perform **1 repeat**
#
# For five separate timing results:
#
# ```python
# for _ in range(5):
#     %time fib_recursive(40)
# ```
#
# Ensure there is no `n=1` before the expression; that caused the shown `SyntaxError`.
