# %% [markdown]
# # Ask Demo

# %%
# %load_ext yukti

# %%
# %%ask --edit
# write me a fibonacci function
# Out:
# Added a code cell below.

# %%
def fibonacci(n):
    """Return the nth Fibonacci number (0-indexed) using recursion."""
    if not isinstance(n, int) or isinstance(n, bool):
        raise TypeError("n must be an integer")
    if n < 0:
        raise ValueError("n must be non-negative")
    if n < 2:
        return n
    return fibonacci(n - 1) + fibonacci(n - 2)

# %%
# %%ask
# how do i run this?
# Out:
# Run the function by calling it in a new code cell:
#
# ```python
# fibonacci(10)
# ```
#
# Then press **Shift+Enter**. It should output:
#
# ```text
# 55
# ```
#
# The argument is zero-indexed: `fibonacci(0)` returns `0`, and `fibonacci(1)` returns `1`.

# %%
fibonacci(10)
# Out:
# 55
