# %%
# %reload_ext autoreload
# %autoreload 2
# %load_ext yukti
# %env AD_MAX_ITEMS=1000
# %env AD_SHOW_FULL_STRINGS=1
from torch_snippets import *
# Out:
# env: AD_MAX_ITEMS=1000
# env: AD_SHOW_FULL_STRINGS=1

# %%
# %%yukti
# permissions: full
# Out:
# **Yukti** — every later `%%ask` cell is now going to run with:
#
# | setting | value |
# | --- | --- |
# | `permissions` | full |
# | `sandbox` | danger-full-access |
# | `approvals` | never |
# | `cwd` | kernel directory |
# | `network` | on |
# | `tools` | on |
# | `run` | on |
# | `writable_roots` | none |
#
# Write `%%yukti` alone for the full vocabulary.

# %%
# %%ask
# give me a random integer
# Out:
# 47

# %%
# %%ask
# give me the next integer
# Out:
# 51

# %%
# %%ask
# give me the next integer as per arithmetic progression
# Out:
# 55

# %%
55 - 51
# Out:
# 4

# %%
51 - 47
# Out:
# 4
